# %% [markdown]
# # DataCamp Analyst Associate Practical Exam Submission

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Ask
# For every column in the data:
# a. State whether the values match the description given in the table above.
# b. State the number of missing values in the column.
# c. Describe what you did to make values match the description if they did not
# match.
#
# ## Solution
#
# **claim_id**
# There were 2000 unique values that match the description given. There were no missing values. No changes were made to this column.
#
# **time_to_close**
# There were 256 unique values that match the description given. There were no missing values. No changes were made to this column.
#
# **claim_amount**
# There were 2000 unique values that match the description given. There were no missing values. If this column was to be used in the analysis, the following modifications would be completed: 1) remove _"R$ "_ from the beginning of each value, 2) cast each value in decimal format.
#
# **amount_paid**
# There were 1964 unique values that match the description given. There were 36 missing values. The missing values were replaced with the median amount paid of the remaining data per the description (20105.70).
#
# **location**
# There were 4 unique values (“RECIFE”, “SAO LUIS”, “FORTALEZA”, and “NATAL) that match the description given. There were no missing values. No changes were made to this column.
#
# **individuals_on_claim**
# There were 15 unique values that match the description given. There were no missing values. No changes were made to this column.
#
# **linked_cases**
# There were 3 unique values in this column: TRUE, FALSE, or missing. There were 26 missing values. All missing values were replaced with _FALSE_ per the description given.
#
# **cause**
# There were 5 unique values in this column: " Meat", meat, vegetable, and VEGETABLES. There were no missing values. _"VEGETABLES"_ was replaced with _vegetable_ and _" Meat"_ was replaced with _meat_, per the description given.

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# ## Ask
# Create a visualization that shows the number of claims in each location. Use the
# visualization to:
# a. State which category of the variable location has the most observations
# b. Explain whether the observations are balanced across categories of the
# variable location
#
# ## Solution
# ![Datacamp_Practical Exam Task 2_1](Datacamp_Practical%20Exam%20Task%202_1.jpg)
# There are four possible locations included in the data. The two locations with the most food claims are Recife and Sao Luis. The food claim count is unbalanced for the four locations. 70% of claims in this analysis occurred at Recife or Sao Luis.
#
# There are three possible food claim causes: meat, vegetables, or unknown. In the graphic below, the majority of food claims across all locations are caused by meat.
# ![Datacamp_Practical Exam Task 2_2](Datacamp_Practical%20Exam%20Task%202_2.jpg)

# %% [markdown]
# ## Ask
# Describe the distribution of time to close for all claims. Your answer must include a visualization that shows the distribution.
#
# ## Solution
# As the legal team thinks that the time to close a food claim will be important, we should look at how the time to close a claim is distributed.
#
# Looking at the times to close a claim, we can see from the graphic below that most claims are closed between 140 and 230 days. The distribution is normally distributed. There are some outliers that close before 90 days or after 280 days, but this is uncommon.
#
# ![Datacamp_Practical Exam Task 3](Datacamp_Practical%20Exam%20Task%203.jpg)

# %% [markdown]
# ## Data Analysis & Insights

# %% [markdown]
# Describe the relationship between time to close and location. Your answer must
# include a visualization to demonstrate the relationship
#
# ## Solution
# Lastly, we review the relationship between the time to close food claims and location. In the graph below, we see the outliers indicate that:
# -  the Sao Luis location closes food claims the longest of all locations,
# -  the Recife location closes food claims longer (than usual) more often.
#
# ![Datacamp_Practical Exam Task 4_1](Datacamp_Practical%20Exam%20Task%204_1.jpg)
#
# In the graph below, we see the time to close claims without outlier data. The interquartile ranges for each location are similar. The Recife location contains 44% of the total food claims in the dataset. Thus, this location would be a good location to begin identifying potential bottlenecks to improve food claim closing times.
#
# ![Datacamp_Practical Exam Task 4_2](Datacamp_Practical%20Exam%20Task%204_2.jpg)
